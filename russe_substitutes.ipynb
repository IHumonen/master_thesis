# %%
import sklearn
import torch

import numpy as np
import pandas as pd

import plotly.express as px

from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.cluster import adjusted_rand_score
from transformers import pipeline

# %% [markdown]
# ## Данные

# %%
task = 'bts-rnc' #'active-dict' 'bts-rnc' 'wiki-wiki'

number_of_clusters = {'wiki-wiki' : 2, 'bts-rnc' : 3, 'active-dict' : 3}

# %%
train_df = pd.read_csv(f'../russe-wsi-kit/data/main/{task}/train.csv', delimiter='\t')

# %%
train_df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id positions  \
# 0              1  балка              1               NaN     90-94
# 1              2  балка              1               NaN     69-73
# 2              3  балка              1               NaN   115-121
# 3              4  балка              1               NaN     85-90
# 4              5  балка              1               NaN     66-70
# ...          ...    ...            ...               ...       ...
# 3486        3487  штамп              4               NaN     81-86
# 3487        3488  штамп              4               NaN     85-90
# 3488        3489  штамп              4               NaN     71-77
# 3489        3490  штамп              4               NaN   107-112
# 3490        3491  штамп              4               NaN    95-100
#
#                                                 context
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3491 rows x 6 columns]

# %%
train_df = train_df.iloc[train_df['positions'].dropna().index]

# %%
train_df['positions'] = train_df['positions'].apply(lambda x: x.split(','))

# %%
train_df['positions'] = train_df['positions'].apply(lambda x: x[0].split('-'))

# %%
train_df[train_df['context'].apply(lambda x: len(x.split('.'))) != 1]
# Out:
#       context_id   word  gold_sense_id  predict_sense_id   positions  \
# 0              1  балка              1               NaN    [90, 94]
# 1              2  балка              1               NaN    [69, 73]
# 2              3  балка              1               NaN  [115, 121]
# 3              4  балка              1               NaN    [85, 90]
# 4              5  балка              1               NaN    [66, 70]
# ...          ...    ...            ...               ...         ...
# 3485        3486  штамп              4               NaN   [98, 104]
# 3486        3487  штамп              4               NaN    [81, 86]
# 3487        3488  штамп              4               NaN    [85, 90]
# 3488        3489  штамп              4               NaN    [71, 77]
# 3490        3491  штамп              4               NaN   [95, 100]
#
#                                                 context
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3485  одновременно типично русской страстностью. В П...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3163 rows x 6 columns]

# %%
train_df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id   positions  \
# 0              1  балка              1               NaN    [90, 94]
# 1              2  балка              1               NaN    [69, 73]
# 2              3  балка              1               NaN  [115, 121]
# 3              4  балка              1               NaN    [85, 90]
# 4              5  балка              1               NaN    [66, 70]
# ...          ...    ...            ...               ...         ...
# 3486        3487  штамп              4               NaN    [81, 86]
# 3487        3488  штамп              4               NaN    [85, 90]
# 3488        3489  штамп              4               NaN    [71, 77]
# 3489        3490  штамп              4               NaN  [107, 112]
# 3490        3491  штамп              4               NaN   [95, 100]
#
#                                                 context
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3491 rows x 6 columns]

# %% [markdown]
# ## ruRoberta

# %%
def get_substitutes(context, positions, top_k=25):
        
    with_mask = ''
    
    for i, symbol in enumerate(context):
        if i == int(positions[0]):
            with_mask += '<mask>'
        elif int(positions[0]) < i < int(positions[1]):
            pass
        else:
            with_mask += symbol
            
    dicts = unmasker(with_mask, top_k=top_k)
    
    substitutes = []
    
    for d in dicts:
        substitutes.append(d['token_str'])
            
    return substitutes

# %%
unmasker = pipeline("fill-mask", model="sberbank-ai/ruRoberta-large")

# %%
# batch_size = 16

# %%
# %%time
# переписать с батчами
train_df['subs'] = train_df.apply(lambda x: get_substitutes(x['context'], x['positions']), axis=1)
# Out:
# CPU times: user 26min 40s, sys: 37.7 s, total: 27min 18s
# Wall time: 27min 3s

# %%
train_df['subs'] = train_df['subs'].apply(lambda x: ''.join(x))

# %%
train_df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id   positions  \
# 0              1  балка              1               NaN    [90, 94]
# 1              2  балка              1               NaN    [69, 73]
# 2              3  балка              1               NaN  [115, 121]
# 3              4  балка              1               NaN    [85, 90]
# 4              5  балка              1               NaN    [66, 70]
# ...          ...    ...            ...               ...         ...
# 3486        3487  штамп              4               NaN    [81, 86]
# 3487        3488  штамп              4               NaN    [85, 90]
# 3488        3489  штамп              4               NaN    [71, 77]
# 3489        3490  штамп              4               NaN  [107, 112]
# 3490        3491  штамп              4               NaN   [95, 100]
#
#                                                 context  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                                    subs
# 0      рам скоб преград глыб тяг плит толщ дек желез...
# 1      лав глыб дач Дум Госдум муз управ дум сум рас...
# 2      связ тяж консол усил тяг кил креп рядами рам ...
# 3      стату гир брон колод гру Библи библи но кастр...
# 4      рам коллег тещ касс преград клав груш каск ст...
# ...                                                 ...
# 3486   штамп стереотип миф характер скреп прототип н...
# 3487   устав протокол статус донос паспорт интернет ...
# 3488  - - кли х штамп ст стереотип ш л/ лай " слов и...
# 3489   стереотип этап пласт артефакт отход скреп аз ...
# 3490   штамп стереотип миф характер детектив посыл л...
#
# [3491 rows x 7 columns]

# %% [markdown]
# ## K-means and Agglomerative clustering

# %%
def make_plot(df, score):
    title = df['word'].iloc[0] + f', {score}'
    labels_true = df['gold_sense_id'].apply(str).to_numpy()
    pca = sklearn.decomposition.PCA(n_components=3)
    d3 = pca.fit_transform(np.stack(df['embedding'].to_numpy()))
    d3 = pd.DataFrame(d3)
    d3['index'] = list(df.index)
    fig = px.scatter_3d(d3, x=0, y=1, z=2, color=labels_true, title=title, hover_data=['index'])
    fig.show()

# %%
def clustering(train_df, clusterizator_class, kwargs=None, print_every=10):
    words_info = {}
    total = 0
    ari_sum = 0
    for i, word in enumerate(set(train_df['word'])):
        df = train_df[train_df['word']==word]
        n_clusters = number_of_clusters[task]
        n_contexts = df.shape[0]
        labels_true = df['gold_sense_id'].to_numpy()
        vectorizer = TfidfVectorizer()
        corpus = list(df['subs'])
        X = vectorizer.fit_transform(corpus)
        if kwargs is None:
            clusterizator = clusterizator_class(n_clusters=n_clusters)
        else:
            clusterizator = clusterizator_class(n_clusters=n_clusters, **kwargs)
        labels_pred = clusterizator.fit_predict(X)#+1
        ari = adjusted_rand_score(labels_true, labels_pred)
        words_info[word] = {'ari' : ari, 'count' : n_contexts}
        ari_sum += ari*n_contexts
        total += n_contexts
#         if task == 'wiki-wiki' or i % print_every == 0:
#             make_plot(df, ari)            
        
    return words_info, total, ari_sum

# %%
words_info, total, ari_sum = clustering(train_df, KMeans, kwargs={'init' : 'random', 'max_iter' : 1000})

# %%
words_info
# Out:
# {'лев': {'ari': -0.0051654701453335665, 'count': 44},
#  'поток': {'ari': -0.0038720647623624216, 'count': 136},
#  'полис': {'ari': -0.007761667929806996, 'count': 142},
#  'проспект': {'ari': -0.01668108995885783, 'count': 139},
#  'купюра': {'ari': -0.005910116395618588, 'count': 150},
#  'среда': {'ari': 0.5209547849622328, 'count': 144},
#  'балка': {'ari': 0.0023199047618045155, 'count': 119},
#  'жаба': {'ari': 0.34867986559534925, 'count': 121},
#  'штамп': {'ari': 0.02587698211567627, 'count': 96},
#  'губа': {'ari': -0.016518914805094438, 'count': 137},
#  'лайка': {'ari': 0.08535507002816398, 'count': 99},
#  'клетка': {'ari': 0.11430237786305952, 'count': 150},
#  'опушка': {'ari': -0.006496425983627991, 'count': 148},
#  'рысь': {'ari': 0.19323326028347065, 'count': 120},
#  'горн': {'ari': 0.09962962962962962, 'count': 51},
#  'лира': {'ari': 0.35245209044512793, 'count': 49},
#  'вид': {'ari': -0.015928311074613535, 'count': 77},
#  'пропасть': {'ari': -0.0005703616362916373, 'count': 127},
#  'крыло': {'ari': 0.05597705255412963, 'count': 91},
#  'пытка': {'ari': -0.060331771953436884, 'count': 143},
#  'хвост': {'ari': -0.047477226819805984, 'count': 121},
#  'курица': {'ari': 0.02944596645446124, 'count': 93},
#  'мина': {'ari': 0.23125100135455962, 'count': 65},
#  'лавка': {'ari': 0.14657709322249649, 'count': 149},
#  'пост': {'ari': 0.011219008478092679, 'count': 144},
#  'проказа': {'ari': 0.2542343355626472, 'count': 146},
#  'оклад': {'ari': 0.001334942824685888, 'count': 146},
#  'мишень': {'ari': 0.21992089925062447, 'count': 121},
#  'обед': {'ari': 0.01319535945307189, 'count': 100},
#  'винт': {'ari': 0.028331588248020536, 'count': 123}}

# %%
ari_sum/total
# Out:
# 0.08083442346985649

# %%
words_info_ac, total_ac, ari_sum_ac = clustering(train_df, AgglomerativeClustering)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1b/x0k2r24j031f5ryslwqynjqh0000gq/T/ipykernel_3247/2283575395.py in <module>
# ----> 1 words_info_ac, total_ac, ari_sum_ac = clustering(train_df, AgglomerativeClustering)
#
# /var/folders/1b/x0k2r24j031f5ryslwqynjqh0000gq/T/ipykernel_3247/2062001152.py in clustering(train_df, clusterizator_class, kwargs, print_every)
#      15         else:
#      16             clusterizator = clusterizator_class(n_clusters=n_clusters, **kwargs)
# ---> 17         labels_pred = clusterizator.fit_predict(X)#+1
#      18         ari = adjusted_rand_score(labels_true, labels_pred)
#      19         words_info[word] = {'ari' : ari, 'count' : n_contexts}
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/cluster/_agglomerative.py in fit_predict(self, X, y)
#    1052             Cluster labels.
#    1053         """
# -> 1054         return super().fit_predict(X, y)
#    1055
#    1056
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/base.py in fit_predict(self, X, y)
#     729         # non-optimized default implementation; override when a better
#     730         # method is possible for a given clustering algorithm
# --> 731         self.fit(X)
#     732         return self.labels_
#     733
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/cluster/_agglomerative.py in fit(self, X, y)
#     915             Returns the fitted instance.
#     916         """
# --> 917         X = self._validate_data(X, ensure_min_samples=2, estimator=self)
#     918         return self._fit(X)
#     919
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
#     562             out = X
#     563         elif no_val_X and not no_val_y:
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     710     if sp.issparse(array):
#     711         _ensure_no_complex_data(array)
# --> 712         array = _ensure_sparse_format(
#     713             array,
#     714             accept_sparse=accept_sparse,
#
# ~/opt/anaconda3/envs/wsi/lib/python3.9/site-packages/sklearn/utils/validation.py in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse)
#     430
#     431     if accept_sparse is False:
# --> 432         raise TypeError(
#     433             "A sparse matrix was passed, but dense "
#     434             "data is required. Use X.toarray() to "
#
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.

# %%
words_info_ac
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1b/x0k2r24j031f5ryslwqynjqh0000gq/T/ipykernel_3247/1876770754.py in <module>
# ----> 1 words_info_ac
#
# NameError: name 'words_info_ac' is not defined

# %%
ari_sum_ac/total_ac
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1b/x0k2r24j031f5ryslwqynjqh0000gq/T/ipykernel_3247/2190696242.py in <module>
# ----> 1 ari_sum_ac/total_ac
#
# NameError: name 'ari_sum_ac' is not defined

# %% [markdown]
# ## Черновик

# %%
train_df.iloc[139]['context'] == train_df.iloc[151]['context']

# %%
train_df.iloc[139]['context']

# %%
train_df.iloc[151]['context']

# %%
train_df.iloc[[139, 151]]

# %%
train_df.iloc[198]['context']

# %%
train_df.iloc[199]['context']

# %%
train_df.iloc[3]['context']

# %%
train_df.iloc[106]['context']

# %%
train_df.iloc[128]['context']
